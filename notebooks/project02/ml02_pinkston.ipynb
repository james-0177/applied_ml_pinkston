# %% [markdown]
# # Project 2: Working with the Titanic Dataset
# **Author:**  James Pinkston
# **Date:**  November 1, 2025
# **Objective:**  P2: Exploratory Data Analysis and Machine Learning Preparation of the Titanic Dataset.

# %% [markdown]
# ## Introduction
# This project uses the Titantic dataset to perform exploratory data analysis and machine learning preparation. I'll import, inspect, explore, and clean the data; and then I'll split the data for training and testing.

# %% [markdown]
# ## Imports
#
# In the code cell below, I will import all of the necessary Python libraries for this notebook:

# %%
# All imports should be at the top of the notebook

# Import seaborn for statistical data visualization (built on matplotlib)

# Import pandas for data manipulation and analysis

# Import scatter matrix

# Import matplotlib for creating static visualizations

# Import train_test_split for basic train/test split

# Import StratifiedShuffleSplit for stratified train/test split
